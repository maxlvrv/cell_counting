# %%
import Augmentor

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /opt/anaconda/envs/deeplearn/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#import torchvision

#keras.utils.np_utils.to_categorical(training_data,2)
p = Augmentor.Pipeline('one_cell', output_directory='output')
#p = Augmentor.Pipeline()
#p.zoom(probability=0.1, min_factor=1.05, max_factor=1.2)
#p.skew_top_bottom(probability=0.2, magnitude=1)
#p.skew_left_right(probability=0.2, magnitude=1)
#p.shear(probability=0.3, max_shear_left=10, max_shear_right=10)
#p.rotate_without_crop(probability=0.3, max_left_rotation=30, max_right_rotation=30, expand=False)
#p.rotate90(probability=0.2)
#p.rotate180(probability=0.2)
#p.random_distortion(probability=0.3, grid_width=5, grid_height=5, magnitude=2)
#p.random_brightness(probability=0.5, min_factor=0.8, max_factor=1.2)
p.status()


batch_size = 1
g = p.keras_generator(batch_size=batch_size)

#train_datagen = ImageDataGenerator(preprocessing_function=p.keras_preprocess_func())
#training_data = train_datagen.flow_from_directory('8-bit_lowfat/training_data', target_size = (80, 80), batch_size = 32, class_mode = 'binary', color_mode = 'grayscale', save_format='tif')

print "Done!\n"
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 0
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.
# Done!

# %%
import matplotlib.pyplot as plt

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");

# %%
p.rotate_without_crop(probability=1, max_left_rotation=30, max_right_rotation=30, expand=False)
p.status()
# Out:
# Operations: 1
# 	0: RotateStandard (max_right_rotation=30.0 max_left_rotation=-30.0 expand=False probability=1 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
import matplotlib.pyplot as plt

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)
p.status()
batch_size = 1
g = p.keras_generator(batch_size=batch_size)
import matplotlib.pyplot as plt

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: Distort (randomise_magnitude=True magnitude=8 grid_height=4 probability=1 grid_width=4 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.flip_left_right(probability=1)
p.status()
batch_size = 1
g = p.keras_generator(batch_size=batch_size)
import matplotlib.pyplot as plt

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: Flip (top_bottom_left_right=LEFT_RIGHT probability=1 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.random_erasing(1, 0.3)
p.status()
batch_size = 1
g = p.keras_generator(batch_size=batch_size)
import matplotlib.pyplot as plt

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: RandomErasing (probability=1 rectangle_area=0.3 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.zoom(probability=1, min_factor=1.4, max_factor=1.4)
p.status()
g = p.keras_generator(batch_size=batch_size)

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: Zoom (min_factor=1.4 max_factor=1.4 probability=1 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.skew_top_bottom(probability=1, magnitude=1)
p.status()
g = p.keras_generator(batch_size=batch_size)

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: Skew (magnitude=1 skew_type=TILT_TOP_BOTTOM probability=1 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.skew_left_right(probability=1, magnitude=1)
p.status()
g = p.keras_generator(batch_size=batch_size)

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: Skew (magnitude=1 skew_type=TILT_LEFT_RIGHT probability=1 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.shear(probability=1, max_shear_left=20, max_shear_right=20)
p.status()
g = p.keras_generator(batch_size=batch_size)

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: Shear (max_shear_right=20 max_shear_left=20 probability=1 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.random_distortion(probability=1, grid_width=5, grid_height=5, magnitude=7)
p.status()
g = p.keras_generator(batch_size=batch_size)

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: Distort (randomise_magnitude=True magnitude=7 grid_height=5 probability=1 grid_width=5 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.random_brightness(probability=1, min_factor=1.5, max_factor=1.5)
p.status()
g = p.keras_generator(batch_size=batch_size)

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: RandomBrightness (min_factor=1.5 max_factor=1.5 probability=1 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %%
p = Augmentor.Pipeline('one_cell', output_directory='output')
p.random_contrast(probability=1, min_factor=0.0, max_factor=0.05)
p.status()
g = p.keras_generator(batch_size=batch_size)

images, labels = next(g, None)

plt.imshow(images[0].reshape(80, 80), cmap="gray");
# Out:
# Initialised with 1 image(s) found.
# Output directory set to one_cell/output.Operations: 1
# 	0: RandomContrast (min_factor=0.0 max_factor=0.05 probability=1 )
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: one_cell
# Dimensions: 1
# 	Width: 80 Height: 80
# Formats: 1
# 	 TIFF
#
# You can remove operations using the appropriate index and the remove_operation(index) function.
